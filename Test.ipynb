# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1, 100, 10)
plt.plot(x)

# %%
x = np.arange(1, 100, 10)
y = np.sin(x)
plt.plot(x, y)
